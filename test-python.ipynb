# %%
message = "Hello, World!"

# %%
print(message)
# Out:
# Hello, World!

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate random data
data = np.random.rand(100, 2) * 100
data = data[data[:, 0].argsort()]  # Sort by x values

data
# Out:
# array([[ 2.18233968, 66.37896862],
#        [ 2.71674212,  6.52045913],
#        [ 3.31893546, 30.39464012],
#        [ 3.36136002,  6.26532035],
#        [ 5.19565776, 78.62781994],
#        [ 6.22731059, 51.25026488],
#        [ 6.53661576, 48.75711937],
#        [ 6.76683619, 70.78350972],
#        [ 7.94065846, 73.14964903],
#        [ 8.3464085 , 88.24163684],
#        [10.06374785, 23.98741128],
#        [10.54737   , 65.67801047],
#        [11.09894692, 44.70555438],
#        [11.40957849, 15.12468287],
#        [14.0711528 , 20.20156684],
#        [14.19719898, 34.79414116],
#        [15.79548228, 69.58991182],
#        [16.22334058,  1.260752  ],
#        [16.47063534, 33.02150649],
#        [16.57745402, 94.5698147 ],
#        [17.48814372, 85.57372589],
#        [18.42248392, 89.398971  ],
#        [18.74119441, 85.81770532],
#        [19.80976328, 56.53302546],
#        [20.13637821, 25.86208349],
#        [20.37664591, 52.33296312],
#        [20.48812742, 87.78300782],
#        [22.531693  , 25.09666613],
#        [22.7179557 , 83.70411252],
#        [23.87962114, 45.12393442],
#        [25.65300624, 65.41746015],
#        [26.02868576, 90.71950307],
#        [26.17056837, 24.69787991],
#        [27.19497261, 75.93982624],
#        [27.69044874, 98.35214727],
#        [27.92760885, 64.28819101],
#        [28.71379581, 79.2854419 ],
#        [30.53106767, 21.26443764],
#        [33.52080474, 17.37615931],
#        [34.73433263, 89.98333457],
#        [35.23749466, 84.14475531],
#        [41.87933191, 26.0157791 ],
#        [44.03234184, 61.52980251],
#        [44.97398425, 77.6710557 ],
#        [45.03509789, 74.8826337 ],
#        [45.83006415, 48.46962871],
#        [45.92651972, 35.77982653],
#        [46.03582712, 86.45636095],
#        [46.2295561 , 41.17655416],
#        [46.39313768, 90.92202059],
#        [46.39324867, 97.20053296],
#        [47.11678989, 82.16368977],
#        [47.12871674, 97.9104938 ],
#        [49.42124473, 82.82492524],
#        [52.33909114, 11.47688719],
#        [53.24206823, 41.10956026],
#        [53.8701798 , 49.7812508 ],
#        [54.35382173,  8.17253457],
#        [54.66482202, 38.0400549 ],
#        [55.97556836, 52.73996221],
#        [57.75933659, 63.45824176],
#        [60.85272727, 34.95063721],
#        [63.41421383, 12.62647416],
#        [63.46712733, 16.59548953],
#        [65.09734672, 54.54318694],
#        [65.11475849, 62.09285675],
#        [65.31627905, 93.83048184],
#        [65.42925523, 15.21042832],
#        [67.07323119, 56.0440631 ],
#        [67.61775621, 32.51040154],
#        [68.63271967,  6.96411482],
#        [69.41505735, 51.26547531],
#        [71.02427986, 31.43501132],
#        [71.20140203, 82.59782127],
#        [71.93536224, 89.0258053 ],
#        [73.0820965 , 98.12970905],
#        [75.67515057, 51.93858595],
#        [77.56118509, 96.44766539],
#        [78.84473433, 66.49849035],
#        [79.32613504, 31.67616771],
#        [79.79141596, 39.59704727],
#        [80.36035354, 50.52067736],
#        [80.64036172, 45.92398776],
#        [81.90635139, 54.0793755 ],
#        [82.21031606, 38.04200075],
#        [84.99753715, 66.90223373],
#        [85.06160578, 56.12227883],
#        [85.7179257 , 90.61432548],
#        [86.01396933, 72.28143032],
#        [87.12044823, 76.60647765],
#        [87.9581855 , 87.0578425 ],
#        [88.19277583, 42.74896879],
#        [90.62545805, 24.95461998],
#        [90.64374533, 13.92453711],
#        [91.50900684, 53.30288672],
#        [93.6822462 ,  5.22578793],
#        [96.33944342, 56.01681835],
#        [96.71266153, 41.77609793],
#        [98.4110319 , 66.79199988],
#        [98.49896561, 77.20124763]])

# %%
# Create a line plot
plt.figure(figsize=(10, 6))
plt.plot(data[:, 0], data[:, 1], 'b-')
plt.grid(True)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Random Data Line Plot')
plt.show()
