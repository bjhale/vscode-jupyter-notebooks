# %%
# %pip install json
# Out:
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json
# Note: you may need to restart the kernel to use updated packages.

# %%
message = "Hello, World!"

# %%
print(message)
# Out:
# Hello, World!

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate random data
data = np.random.rand(100, 2) * 100
data = data[data[:, 0].argsort()]  # Sort by x values

data
# Out:
# array([[ 0.63193002, 36.54415099],
#        [ 2.50907162, 71.22912126],
#        [ 3.3753792 , 87.93947363],
#        [ 3.51076843, 41.99821064],
#        [ 3.5855891 , 71.26462604],
#        [ 3.97032788, 94.68844952],
#        [ 5.10918491, 22.47323817],
#        [ 6.43628694, 78.21078431],
#        [ 6.67721458, 64.21319093],
#        [ 6.88082406, 59.13666472],
#        [ 6.96270558, 22.09648837],
#        [ 7.54314085,  8.10945649],
#        [ 8.80061221, 68.95336776],
#        [ 9.43045151, 22.56116324],
#        [10.20184092, 84.83058375],
#        [10.51145156, 74.83516624],
#        [10.9141175 ,  0.81892557],
#        [14.88960347, 98.45764236],
#        [14.89322398, 40.17341793],
#        [16.2509033 , 17.09447936],
#        [18.33918688, 35.42336837],
#        [18.78215455,  9.94931597],
#        [20.02393715, 70.25605901],
#        [20.08538452, 84.54798273],
#        [20.14323739, 98.27262537],
#        [21.80906542, 61.89191186],
#        [21.97111161, 23.76037551],
#        [22.86186327, 24.50449069],
#        [23.24103179, 16.96636334],
#        [24.55914703, 65.45882518],
#        [25.61823479,  1.49702972],
#        [25.77437787, 48.13768065],
#        [26.57395442, 16.39427229],
#        [28.09914761, 75.40228406],
#        [32.22724715, 25.28920216],
#        [32.68496269, 85.2349703 ],
#        [33.42774556, 73.81041025],
#        [33.43793558, 60.43668516],
#        [33.9148134 , 41.38239021],
#        [34.42250191, 82.49070617],
#        [34.87265486, 29.96321356],
#        [35.0521604 , 64.87357019],
#        [35.68717559, 41.86448107],
#        [36.51255075, 82.82866213],
#        [37.14679172, 10.96119803],
#        [38.33916345, 63.09751663],
#        [38.56145417, 78.81634032],
#        [38.67512446, 20.79759609],
#        [39.40198545, 60.74817639],
#        [39.91682472, 66.79544902],
#        [42.08046048, 17.47496758],
#        [42.43850742, 71.58527528],
#        [44.78316546, 39.21013911],
#        [45.07245902, 39.73492016],
#        [47.5114167 ,  0.64053191],
#        [49.99919343, 18.90732153],
#        [50.56865787,  0.74305502],
#        [50.69092844, 12.3079914 ],
#        [51.16174129, 19.76820212],
#        [51.3857673 , 59.47794664],
#        [51.50158293, 68.76417465],
#        [51.64637749, 84.6349805 ],
#        [52.62697328, 16.32530684],
#        [53.58505941, 42.62479476],
#        [54.53790158, 91.73406681],
#        [55.27520981, 83.29983525],
#        [55.55948895, 86.78783659],
#        [56.51837757, 81.10370594],
#        [56.87541097, 87.40860226],
#        [57.28370534,  4.4608358 ],
#        [57.31266733, 88.84663362],
#        [57.83421315, 49.39048623],
#        [59.72467853, 84.57975071],
#        [59.87928889, 91.65057932],
#        [60.84415357, 13.62943695],
#        [65.07559343,  4.3444318 ],
#        [65.28415573, 93.28191213],
#        [67.44578755, 43.99667178],
#        [68.04789503, 30.51605774],
#        [68.1123018 , 59.04069132],
#        [71.39804241, 26.10459261],
#        [71.81194108, 55.36827443],
#        [73.44965017,  3.39816199],
#        [76.48928671, 95.84871772],
#        [77.74253678, 70.85405246],
#        [78.3119789 , 64.56015619],
#        [81.05283858, 32.94083186],
#        [81.97865665, 42.00590239],
#        [82.39439875, 16.09052392],
#        [83.4996727 , 22.73785852],
#        [83.55903567, 38.74565332],
#        [83.90718674, 11.47003322],
#        [87.10057115, 77.83069846],
#        [87.16742354, 62.25484001],
#        [88.75650638, 94.58958604],
#        [93.54375504,  9.8779985 ],
#        [93.83212184, 56.9516677 ],
#        [95.6189401 , 45.86344941],
#        [95.89163283, 59.51754608],
#        [99.92607595, 10.13161758]])

# %%
# Create a line plot
plt.figure(figsize=(10, 6))
plt.plot(data[:, 0], data[:, 1], 'b-')
plt.grid(True)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Random Data Line Plot')
plt.show()

# %%
#Read the json
import json

with open('test.json', 'r') as f:
    json_data = json.load(f)

json_data
# Out:
# {'foo': 'bar'}
